# %% [markdown]
# # Together's Open Deep Research Cookbook: An Efficient and Open Source Implementation with Multi-Step Web Search
#
# Authors: Shang Zhu, Federico Bianchi, Zhichao Li, Ben Athiwaratkun, Albert Meixner, James Zou
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/togethercomputer/together-cookbook/blob/main/Agents/Together_Open_Deep_Research_CookBook.ipynb)
#
# ## Introduction
#
# Welcome to the Together's Open Deep Research Cookbook! This guide demonstrates how to answer complex research questions with comprehensive, evidence-based reports by combining the power of large language models (LLMs) with structured web search techniques.
#
# We break down the research process into clear, modular steps that can be understood, customized, and improved independently. This modularity makes advanced research capabilities accessible and adaptable to diverse research needs.
#
# ### Together's Open Deep Research Workflow
#
# <img src="https://github.com/vinid/data/blob/master/loop.png?raw=true">
#
#
# Our Deep Research framework offers several key advantages:
#
# 1. **Progressive Exploration**: Starting with initial queries derived from your research topic, the system intelligently explores information, identifies gaps, and refines its search strategy.
#
# 2. **Evidence-Based Synthesis**: All findings are grounded in verified sources with proper citations, reducing the hallucinations common in pure LLM-based question and answering.
#
# 3. **Adaptive Search with Completeness Evaluation**: The system evaluates information gaps against research goals and generates targeted follow-up queries for missing specifics. This ensures resources focus precisely on completing your research rather than collecting redundant information.
#
# 4. **Source Filtering**: Not all information is equally valuable - our system evaluates and prioritizes the most relevant and reliable sources.
#
# 5. **Structured Output**: Results are presented as well-organized reports with clear sections, cohesive narratives, and proper citations.
#
# ### Cookbook Contributions
#
# - Set up a flexible research environment with configurable parameters
# - Process complex topics through a multi-stage research pipeline
# - Generate high-quality reports for the given research topic
#
# The functional design pattern we showcase makes each step transparent and customizable, allowing you to adapt the system to specific domains or research styles. Each function handles a specific part of the research process, from query generation to answer synthesis, with explicit inputs and outputs that can be tested and improved independently.
#
# Whether you're a researcher, student, analyst, or curious explorer, this cookbook provides the tools to transform your research questions into comprehensive, evidence-based reports that would normally require hours of manual work.
#
# Let's begin our exploration of AI-powered research!

# %% [markdown]
# ## Install packages

# %%
# %%capture
# !pip install tavily-python together markdown

# %% [markdown]
# ## Initialize necessary functions and configuration

# %%
from dataclasses import dataclass
from typing import Literal, Optional
from pydantic import BaseModel, Field
import json
import asyncio
from typing import List
from together import AsyncTogether, Together
from tavily import AsyncTavilyClient, TavilyClient

# %% [markdown]
# ### Data Model Definitions
#
# Before diving into the research functionality, we need to define the data structures that will represent our research plan, search results, and source evaluation. These models provide a structured way to handle the different types of data flowing through our research pipeline.
#
# The data model consists of several key components:
#
# 1. **ResearchPlan**: Structures the initial research plan with search queries generated by the LLM
# 2. **SourceList**: Captures the filtered list of relevant sources chosen by the LLM
# 3. **SearchResult**: Represents an individual search result with its metadata and content
# 4. **SearchResults**: A collection of search results with utilities for manipulation and display
#
# These structured data models allow us to maintain organization throughout the research process, from query generation to final report synthesis.
#
# The first two will be pydantic base classes, and it will be used for JSON mode. The latter two will instread be more general dataclasses.

# %%
class ResearchPlan(BaseModel):
    """
    Structured representation of a research plan with search queries.

    Used to parse the LLM's planning output into a structured format
    that can be easily processed by the research pipeline.
    """
    queries: list[str] = Field(description="A list of search queries to thoroughly research the topic")

class SourceList(BaseModel):
    """
    Structured representation of filtered source indices.

    Used to parse the LLM's source evaluation output into a structured
    format that identifies which search results should be retained.
    """
    sources: list[int] = Field(description="A list of source numbers from the search results")

@dataclass
class SearchResult:
    """
    Container for an individual search result with its metadata and content.

    Holds both the original content and the filtered/processed content
    that's relevant to the research topic.
    """
    title: str
    link: str
    content: str
    filtered_raw_content: Optional[str] = None

    def __str__(self):
        """(For Report Generation and Completeness Evaluation) String representation with title, link and refined content."""
        return (
            (f"Title: {self.title}\n" f"Link: {self.link}\n" f"Refined Content: {self.filtered_raw_content}")
            if self.filtered_raw_content
            else (f"Title: {self.title}\n" f"Link: {self.link}\n" f"Raw Content: {self.content[:1000]}")
        )

    def short_str(self):
        """(For Filtering ONLY) Abbreviated string representation with truncated raw content."""
        return f"Title: {self.title}\nLink: {self.link}\nRaw Content: {self.content[:1000]}"


@dataclass
class SearchResults:
    """
    Collection of search results with utilities for manipulation and display.

    Provides methods for combining result sets, deduplication, and
    different string representations for processing and display.
    """
    results: list[SearchResult]

    def __str__(self):
        """Detailed string representation of all search results with indices."""
        return "\n\n".join(f"[{i+1}] {str(result)}" for i, result in enumerate(self.results))

    def __add__(self, other):
        """Combine two SearchResults objects by concatenating their result lists."""
        return SearchResults(self.results + other.results)

    def short_str(self):
        """Abbreviated string representation of all search results with indices."""
        return "\n\n".join(f"[{i+1}] {result.short_str()}" for i, result in enumerate(self.results))

    def dedup(self):
        """
        Remove duplicate search results based on URL.

        Returns a new SearchResults object with unique entries.
        """
        def deduplicate_by_link(results):
            seen_links = set()
            unique_results = []

            for result in results:
                if result.link not in seen_links:
                    seen_links.add(result.link)
                    unique_results.append(result)

            return unique_results

        return SearchResults(deduplicate_by_link(self.results))

# %% [markdown]
# ## Deep Research Configuration Parameters
#
# This section defines the key parameters that control the Deep Research process. These configuration settings allow you to customize the research behavior, model selection, and output format according to your specific needs.
#
# The parameters include:
#
# - **Model Selection**: Defines which LLMs to use for different stages of the research process
# - **Research Budget**: Controls the number of research cycles performed, with higher values enabling more thorough but time-consuming exploration
# - **Query Limits**: Sets boundaries on how many search queries to generate and execute
# - **Source Management**: Configures the maximum amount of sources to be considered in the final synthesis (avoid ultra-long context that may break the context window)
# - **Prompt Templates**: Defines the instruction prompts utilized for selected models.
#
#
# Adjust these parameters to balance depth, speed, and resource usage according to your research priorities.
#
# # Disclaimers ⚠️
#
# **For readability**, here we provide rather simple prompts but we encourage you to optimize them as needed.
#
# **This workflow involves multiple LLM calls and search API calls**, so we remind the user to be mindful about the resource management as defined in the following code block.
#
# **Be sure** to understand that this code will make API requests to other services. Specifically, you will need Tavily API key (get it [here](https://docs.tavily.com/documentation/quickstart)) and Together API key (get it [here](https://docs.together.ai/docs/quickstart)).

# %%
# raise Exception("Please remove this after you read the disclaimers above ☝️")

# Research Configuration
# ======================

# Model Selection
# --------------
# Specialized models for different stages of the research pipeline
planning_model = "Qwen/Qwen2.5-72B-Instruct-Turbo"  # Used for research planning and evaluation
json_model = "meta-llama/Meta-Llama-3.1-70B-Instruct-Turbo"  # Used for structured data parsing
summary_model = "meta-llama/Llama-4-Scout-17B-16E-Instruct"  # Used for web content summarization
answer_model = "meta-llama/Llama-4-Maverick-17B-128E-Instruct-FP8"  # Used for final answer synthesis

# Resource Allocation
# ------------------
# Parameters controlling research depth and breadth
budget = 2  # Number of research refinement cycles to perform (in addition to the initial search operation)
max_queries = 2  # Maximum number of search queries per research cycle
max_sources = 10  # Maximum number of sources to include in final synthesis
max_tokens = 8192 # Maximum number of tokens in the generated report

# System Prompts
# -------------
# Instructions for each stage of the research process
prompts = {
    # Planning: Generates initial research queries
    "planning_prompt": """You are a strategic research planner with expertise in breaking down complex
                         questions into logical search steps. Generate focused, specific, and self-contained queries that
                         will yield relevant information for the research topic.""",

    # Plan Parsing: Extracts structured data from planning output
    "plan_parsing_prompt": """Extract search queries that should be executed.""",

    # Content Processing: Identifies relevant information from search results
    "raw_content_summarizer_prompt": """Extract and synthesize only the information relevant to the research
                                       topic from this content. Preserve specific data, terminology, and
                                       context while removing irrelevant information.""",

    # Completeness Evaluation: Determines if more research is needed
    "evaluation_prompt": """Analyze these search results against the original research goal. Identify
                          specific information gaps and generate targeted follow-up queries to fill
                          those gaps.
                          Explain how the gaps are identified and measured.
                          If no significant gaps exist, indicate that research is complete.""",

    # Evaluation Parsing: Extracts structured data from evaluation output
    "evaluation_parsing_prompt": """Extract follow-up search queries from the evaluation. If no follow-up queries are needed, return an empty list.""",

    # Source Filtering: Selects most relevant sources
    "filter_prompt": """Evaluate each search result for relevance, accuracy, and information value
                       related to the research topic. At the end, you need to provide a list of
                       source numbers with the rank of relevance. Remove the irrelevant ones.""",
    # Source Filtering: Selects most relevant sources
    "source_parsing_prompt": """Extract the source list that should be included.""",

    # Answer Generation: Creates final research report
    "answer_prompt": """Create a comprehensive, publication-quality markdown research report based exclusively
                       on the provided sources. The report should include: title, introduction, analysis (multiple sections with insights titles)
                       and conclusions, references. Use proper citations (source with link; using \n\n \\[Ref. No.\\] to improve format),
                       organize information logically, and synthesize insights across sources. Include all relevant details while
                       maintaining readability and coherence. In each section, You MUST write in plain
                       paragraghs and NEVER describe the content following bullet points or key points (1,2,3,4... or point X: ...)
                       to improve the report readability."""
}

# Initialize Clients
# ------------------
# Initialize the Together and Tavily clients with your API keys
together_client = AsyncTogether(api_key="fb82f64aeaf086ed9dccd4e038ee856877b170301beed1d995d43afcc7227a49")
tavily_client = AsyncTavilyClient(api_key="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")
sync_together_client = Together(api_key="fb82f64aeaf086ed9dccd4e038ee856877b170301beed1d995d43afcc7227a49")
sync_tavily_client = TavilyClient(api_key="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")

# %% [markdown]
# ## Building the Research Pipeline
#
# ### STEP 1: Query Generation - Breaking Down the Research Question
#
# In this first stage, we transform the broad research topic into specific, targeted search queries. This crucial step determines what information we'll gather and sets the foundation for the entire research process.

# %%
async def generate_initial_queries(topic: str, together_client: AsyncTogether, max_queries: int, planning_model: str, json_model: str, prompts: dict) -> List[str]:
    """Step 1: Generate initial research queries based on the topic"""
    queries = await generate_research_queries(topic, together_client, planning_model, json_model, prompts)
    if max_queries > 0:
        queries = queries[:max_queries]
    print(f"\n\nInitial queries: {queries}")

    if len(queries) == 0:
        print("ERROR: No initial queries generated")
        return []

    return queries

async def generate_research_queries(topic: str, together_client: AsyncTogether, planning_model: str, json_model: str, prompts: dict) -> list[str]:
    """Generate research queries for a given topic using LLM"""
    PLANNING_PROMPT = prompts["planning_prompt"]

    planning_response = await together_client.chat.completions.create(
        model=planning_model,
        messages=[
            {"role": "system", "content": PLANNING_PROMPT},
            {"role": "user", "content": f"Research Topic: {topic}"}
        ]
    )
    plan = planning_response.choices[0].message.content

    print(f"Generated plan: {plan}")

    SEARCH_PROMPT = prompts["plan_parsing_prompt"]

    json_response = await together_client.chat.completions.create(
        model=json_model,
        messages=[
            {"role": "system", "content": SEARCH_PROMPT},
            {"role": "user", "content": f"Plan to be parsed: {plan}"}
        ],
        response_format={"type": "json_object", "schema": ResearchPlan.model_json_schema()}
    )

    response_json = json_response.choices[0].message.content
    plan = json.loads(response_json)
    return plan["queries"]

# %% [markdown]
# **In `generate_research_queries` function:** We use a two-model approach where the planning model creates comprehensive research strategies, then the JSON model structures these into precisely formatted queries. This ensures both creative planning and reliable structured output.
#
# **The `generate_initial_queries` function** wraps this process, applying query limits and providing additional validation and logging before returning the final set of targeted search queries.
#
# Let's demonstrate this process with a practical example, using the research topic: "The impact of artificial intelligence on the manufacturing industry" This multifaceted subject provides an excellent case study for showing how our system breaks down complex topics into targeted queries.
#
# **Note: In rare cases we saw none initial queries were generated, where rerunning the cell would typically resolve the issue.**

# %%
research_topic="The impact of artificial intelligence on the manufacturing industry"

initial_queries = await generate_initial_queries(
    topic=research_topic,
    together_client=together_client,
    max_queries=max_queries,
    planning_model=planning_model,
    json_model=json_model,
    prompts=prompts
)
# Out:
# Generated plan: To effectively research the impact of artificial intelligence (AI) on the manufacturing industry, you can break down the topic into several focused, specific, and self-contained queries. Each query will help gather relevant information that contributes to a comprehensive understanding of the topic. Here are the queries:
#
# 1. **Overview of AI in Manufacturing:**
#    - What are the key applications of AI in the manufacturing industry?
#    - How has the adoption of AI in manufacturing evolved over the past decade?
#
# 2. **Economic Impact:**
#    - What are the economic benefits of AI in manufacturing, such as cost reduction and efficiency gains?
#    - How has AI influenced the job market in the manufacturing sector, including job creation and displacement?
#
# 3. **Operational Efficiency:**
#    - How does AI improve production efficiency and quality control in manufacturing?
#    - What are the specific AI technologies (e.g., machine learning, robotics, predictive maintenance) used to enhance operational efficiency?
#
# 4. **Supply Chain Management:**
#    - How does AI optimize supply chain management in manufacturing?
#    - What are the best practices for integrating AI into supply chain operations?
#
# 5. **Product Innovation:**
#    - How does AI contribute to product innovation and design in manufacturing?
#    - What are some examples of AI-driven product innovations in the manufacturing industry?
#
# 6. **Challenges and Barriers:**
#    - What are the main challenges and barriers to AI adoption in manufacturing?
#    - How do regulatory and ethical considerations impact the use of AI in manufacturing?
#
# 7. **Case Studies:**
#    - Provide case studies of successful AI implementations in manufacturing companies.
#    - What lessons can be learned from these case studies?
#
# 8. **Future Trends:**
#    - What are the emerging trends in AI for manufacturing?
#    - How might AI transform the manufacturing industry in the next 5-10 years?
#
# 9. **Stakeholder Perspectives:**
#    - What are the perspectives of key stakeholders (e.g., manufacturers, policymakers, employees) on the impact of AI in manufacturing?
#    - How are these stakeholders addressing the challenges and opportunities presented by AI?
#
# 10. **Comparative Analysis:**
#     - How does the impact of AI in manufacturing compare to its impact in other industries?
#     - What can the manufacturing industry learn from the AI adoption in other sectors?
#
# By addressing these specific queries, you can build a robust and detailed research report on the impact of artificial intelligence on the manufacturing industry.
#
#
# Initial queries: ['What are the key applications of AI in the manufacturing industry?', 'How has the adoption of AI in manufacturing evolved over the past decade?']

# %% [markdown]
# Below are the targeted queries generated by our system, demonstrating how the general research topic has been decomposed into specific, searchable questions. Each query addresses a distinct aspect of AI's impact on the manufacturing industry:

# %%
initial_queries
# Out:
# ['What are the key applications of AI in the manufacturing industry?',
#  'How has the adoption of AI in manufacturing evolved over the past decade?']

# %% [markdown]
# ### STEP 2: Information Gathering - Searching and Processing Web Content
#
# Now that we have our targeted queries, we move to the information gathering phase. This step involves two critical processes:
#
# 1. **Web Search**: Executing our queries against web sources to retrieve relevant information
# 2. **Content Processing**: Filtering and summarizing the raw content to extract what's most relevant to our research, using an LLM (`summary_model`).
#
# #### Let's first examine a single search operation (using [Tavily Search API](https://tavily.com/) as an example) to understand the core mechanics:

# %%
import asyncio
import time

def tavily_search(query: str, tavily_client: TavilyClient, prompts: dict, together_client: Together, summary_model: str) -> SearchResults:
  """Perform a single Tavily search"""
  print(f'Perform Tavily search with query: {query}')

  response = tavily_client.search(query, include_raw_content=True)

  print(f"Tavily Responded with {len(response['results'])} results (Tavily returning None will be ignored for summarization)")

  RAW_CONTENT_SUMMARIZER_PROMPT = prompts["raw_content_summarizer_prompt"]

  # Create tasks for summarization
  summarization_tasks = []
  result_info = []
  for result in response["results"]:
      if result["raw_content"] is None:
          continue
      # Increased delay to respect rate limits
      # await asyncio.sleep(60)  # Wait for 60 seconds before making the request
      print("Before summarize_content async")
      task = summarize_content(result["raw_content"], query, RAW_CONTENT_SUMMARIZER_PROMPT, together_client, summary_model)
      print("After summarize_content async")
      summarization_tasks.append(task)
      result_info.append(result)

  print("Before gathering")
  summarized_contents = summarization_tasks # await asyncio.gather(*summarization_tasks)
  print("After gathering")

  formatted_results = []
  for result, summarized_content in zip(result_info, summarized_contents):
      formatted_results.append(
          SearchResult(
              title=result["title"],
              link=result["url"],
              content=result["raw_content"],
              filtered_raw_content=summarized_content,
          )
      )
  return SearchResults(formatted_results)

def summarize_content(raw_content: str, query: str, prompt: str, together_client: Together, summary_model: str) -> str:
  """Summarize content asynchronously using the LLM"""
  print("Summarizing content asynchronously using the LLM")

  # Increased delay to respect rate limits
  # await asyncio.sleep(60)  # Wait for 60 seconds before making the request

  summarize_response = together_client.chat.completions.create(
      model=summary_model,
      messages=[
          {"role": "system", "content": prompt},
          {"role": "user", "content": f"<Raw Content>{raw_content}</Raw Content>\n\n<Research Topic>{query}</Research Topic>"}
      ]
  )
  print("Returning LLM response")
  return summarize_response.choices[0].message.content

# %% [markdown]
# To demonstrate the search and content processing mechanism, let's execute a single search using the first query from our generated list. This allows us to examine in detail how the system retrieves and processes information before we implement the full multi-query research workflow:

# %%
search_results=tavily_search(initial_queries[0], sync_tavily_client, prompts, sync_together_client, summary_model)
# Out:
# Perform Tavily search with query: What are the key applications of AI in the manufacturing industry?
# Tavily Responded with 5 results (Tavily returning None will be ignored for summarization)
# Before summarize_content async
# Summarizing content asynchronously using the LLM
# Returning LLM response
# After summarize_content async
# Before summarize_content async
# Summarizing content asynchronously using the LLM
# Returning LLM response
# After summarize_content async
# Before summarize_content async
# Summarizing content asynchronously using the LLM
# Returning LLM response
# After summarize_content async
# Before summarize_content async
# Summarizing content asynchronously using the LLM
# Returning LLM response
# After summarize_content async
# Before gathering
# After gathering

# %% [markdown]
# Below is an example of the first retrieved and summarized result. Note how the system has not only found relevant content but also processed it to extract information specifically related to our research topic. This demonstrates the content filtering capabilities that make our research pipeline more effective than simple search retrieval:

# %%
print(f"Title: {search_results.results[0].title}\n\nLink: {search_results.results[0].link}\n\nContent: {search_results.results[0].filtered_raw_content[:1000]}[...]")
# Out:
# Title: AI in Manufacturing : Key Use Cases and benefits for 2025 and Beyond
#
# Link: https://www.softlabsgroup.com/blogs/ai-in-manufacturing/
#
# Content: ## Key Applications of AI in Manufacturing
#
# The integration of Artificial Intelligence (AI) in the manufacturing industry is transforming operations, enhancing efficiency, and driving innovation. Here are the key applications of AI in manufacturing:
#
# ### 1. **Predictive Maintenance & Equipment Health Monitoring**
# - **Application**: AI analyzes sensor data to detect early signs of equipment failure, reducing unexpected downtime and extending machine life.
# - **Benefits**: Proactive scheduling of maintenance, reduction in costly breakdowns.
#
# ### 2. **Automated Quality Inspection & Defect Detection**
# - **Application**: AI-powered vision systems analyze production lines in real-time to detect defects and anomalies.
# - **Benefits**: Minimizes rework, reduces waste, and ensures high-quality output.
#
# ### 3. **Supply Chain & Inventory Optimization**
# - **Application**: AI-driven demand forecasting helps maintain optimal inventory levels, reducing overstocking and material shortages.
# - **Benefits*[...]

# %% [markdown]
# #### Executing the Complete Initial Search Process
#
# Now that we understand how a single search works, let's implement the parallel search process that executes all our initial queries simultaneously. This approach significantly improves efficiency by:
#
# 1. Running multiple search operations concurrently
# 2. Processing all results in parallel
# 3. Combining findings into a comprehensive result set
#
#
# **Disclaimer: This step involves multiple LLM runs processing long web texts, so we remind the user to be mindful about the resource management as defined at the beginning.**
#
# This demonstrates a key advantage of our functional pipeline architecture:

# %%
def perform_search(queries: List[str], tavily_client: TavilyClient, prompts: dict, together_client: Together, summary_model: str) -> SearchResults:
  """Execute searches for all queries in parallel"""
  print(f"Performing search for {len(queries)} queries")
  tasks = [tavily_search(query, tavily_client, prompts, together_client, summary_model) for query in queries]
  results_list = tasks # await asyncio.gather(*tasks)

  combined_results = SearchResults([])
  for results in results_list:
      combined_results = combined_results + results

  combined_results_dedup=combined_results.dedup()
  print(f"Search complete, found {len(combined_results_dedup.results)} results after deduplication")
  return combined_results_dedup

# %%
initial_results=perform_search(initial_queries, sync_tavily_client, prompts, sync_together_client, summary_model)
# Out:
# Performing search for 2 queries
# Perform Tavily search with query: What are the key applications of AI in the manufacturing industry?
# Tavily Responded with 9 results (Tavily returning None will be ignored for summarization)
# Before summarize_content async
# Summarizing content asynchronously using the LLM
# Returning LLM response
# After summarize_content async
# Before summarize_content async
# Summarizing content asynchronously using the LLM
# Returning LLM response
# After summarize_content async
# Before summarize_content async
# Summarizing content asynchronously using the LLM
# Returning LLM response
# After summarize_content async
# Before summarize_content async
# Summarizing content asynchronously using the LLM
# Returning LLM response
# After summarize_content async
# Before summarize_content async
# Summarizing content asynchronously using the LLM
# Returning LLM response
# After summarize_content async
# Before summarize_content async
# Summarizing content asynchronously using the LLM
# Returning LLM response
# After summarize_content async
# Before summarize_content async
# Summarizing content asynchronously using the LLM
# Returning LLM response
# After summarize_content async
# Before summarize_content async
# Summarizing content asynchronously using the LLM
# Returning LLM response
# After summarize_content async
# Before gathering
# After gathering
# Perform Tavily search with query: How has the adoption of AI in manufacturing evolved over the past decade?
# Tavily Responded with 5 results (Tavily returning None will be ignored for summarization)
# Before summarize_content async
# Summarizing content asynchronously using the LLM
# Returning LLM response
# After summarize_content async
# Before summarize_content async
# Summarizing content asynchronously using the LLM
# Returning LLM response
# After summarize_content async
# Before summarize_content async
# Summarizing content asynchronously using the LLM
# Returning LLM response
# After summarize_content async
# Before gathering
# After gathering
# Search complete, found 6 results after deduplication

# %% [markdown]
# Below is the complete set of results from our parallel search operations, consolidated into a single collection. This demonstrates how our system gathers diverse information across multiple queries while maintaining organization. The results include sources addressing different aspects of our research topic, providing a foundation for comprehensive analysis.

# %%
print(f"First 10000 characters of {len(initial_results.results)} results:\n\n {str(initial_results)[:10000]}\n\n...\n\n Last 10000 characters of {len(initial_results.results)} results:\n\n {str(initial_results)[-10000:]}\n\n")
# Out:
# First 10000 characters of 6 results:
#
#  [1] Title: AI in Manufacturing : Key Use Cases and benefits for 2025 and Beyond
# Link: https://www.softlabsgroup.com/blogs/ai-in-manufacturing/
# Refined Content: Here are the key applications of AI in the manufacturing industry:
#
# 1. **Predictive Maintenance & Equipment Health Monitoring**: AI detects early signs of equipment failure, reducing unexpected downtime and extending machine life.
# 2. **Automated Quality Inspection & Defect Detection**: AI-powered vision systems analyze production lines in real-time to detect defects and anomalies.
# 3. **Supply Chain & Inventory Optimization**: AI-driven demand forecasting helps manufacturers maintain optimal inventory levels, reducing overstocking and material shortages.
# 4. **Process Optimization & Waste Reduction**: AI continuously analyzes production data to optimize workflows, energy consumption, and material usage.
# 5. **Production Line Automation & Robotics Integration**: AI enables robotic systems to handle complex assembly, packaging, and material movement tasks with precision.
# 6. **Digital Twin for Manufacturing Simulation**: AI-powered digital twins create virtual replicas of production facilities, allowing manufacturers to test changes and predict performance outcomes.
# 7. **Worker Safety & Hazard Detection**: AI monitors workplace conditions and worker activity to detect safety risks, such as exposure to hazardous materials or unsafe equipment handling.
# 8. **Energy Efficiency & Smart Resource Management**: AI optimizes energy consumption by analyzing usage patterns and adjusting operations accordingly.
#
# **Top Use Cases of AI in Manufacturing:**
#
# 1. **AI-Powered Inventory Optimization**: AI-driven inventory management systems continuously monitor stock levels in real-time, predict demand fluctuations, and automate restocking processes.
# 2. **AI-Driven Production Monitoring**: AI-powered production tracking systems analyze real-time sensor data from machines to detect anomalies, optimize workflows, and enhance productivity.
# 3. **PPE Compliance Monitoring for Worker Safety**: AI-powered computer vision systems monitor workers in real-time to detect whether they are wearing required safety gear.
# 4. **AI-Enabled Load Security Monitoring**: AI-powered monitoring systems analyze vehicle loads in real-time, ensuring they are properly secured before transportation.
# 5. **AI-Powered Vehicle Identification for Secure Logistics**: AI-powered vehicle recognition systems use computer vision and real-time data processing to authenticate vehicle make, model, and license plates.
# 6. **AI-Driven Fleet Optimization for Manufacturing Logistics**: AI-driven fleet management systems analyze real-time GPS data, traffic patterns, and vehicle conditions to optimize routes, predict maintenance needs, and reduce idle times.
#
# These applications and use cases demonstrate the significant impact of AI on the manufacturing industry, from improving efficiency and productivity to enhancing quality control and worker safety.
#
# [2] Title: How is AI being used in Manufacturing | IBM
# Link: https://www.ibm.com/think/topics/ai-in-manufacturing
# Refined Content: **Key Applications of AI in Manufacturing**
#
# Artificial intelligence (AI) is transforming the manufacturing industry by enhancing efficiency, precision, and adaptability in various production processes. The key applications of AI in manufacturing include:
#
# 1. **Predictive Maintenance**: AI analyzes sensor data from machinery to forecast failures before they occur, reducing unexpected downtimes and maintenance costs.
# 2. **Quality Control**: AI-powered computer vision systems scan products in real-time to identify defects, improving product quality and reducing waste.
# 3. **Digital Twin Technology**: AI creates virtual replicas of processes, production lines, factories, and supply chains to simulate, analyze, and predict performance in real-time.
# 4. **Collaborative Robots (Cobots)**: AI-powered cobots work safely alongside humans, handling repetitive or physically demanding tasks and enhancing productivity and safety.
# 5. **Generative Design**: AI-driven generative design technology explores a wide array of design options based on parameters such as materials and manufacturing constraints, accelerating the design cycle.
# 6. **Supply Chain Management**: AI optimizes supply chains by analyzing vast datasets to predict demand, manage inventory, and streamline logistics.
# 7. **Inventory Management**: AI optimizes inventory levels by analyzing data to predict stock needs and automate replenishment, reducing carrying costs and improving cash flow.
# 8. **Energy Management**: AI systems monitor energy usage in real-time to identify inefficiencies and recommend adjustments that reduce energy costs and minimize environmental impact.
# 9. **Workforce Management**: AI aids in workforce planning and management by analyzing employee data to optimize shifts and improve productivity.
# 10. **Custom Manufacturing**: AI enables manufacturers to offer mass customization, allowing products to be tailored to individual customer preferences without slowing down production.
#
# These applications of AI in manufacturing are driving significant benefits, including:
#
# * Increased efficiency
# * Cost reduction
# * Improved decision-making
# * Increased safety
# * Sustainability
# * Innovation and competitive advantage
#
# However, there are also challenges associated with using AI in manufacturing, including data quality and availability, operational risks, skills shortages, cybersecurity concerns, change management, and implementation costs.
#
# [3] Title: Manufacturing AI: Top 15 tools & 13 real-life use cases ['25]
# Link: https://research.aimultiple.com/manufacturing-ai/
# Refined Content: **Key Applications of AI in the Manufacturing Industry**
#
# The manufacturing industry has widely adopted AI, with 93% of leaders stating their organizations are at least moderately using AI. The key applications of AI in manufacturing include:
#
# 1. **Predictive Maintenance**: AI-powered predictive maintenance helps manufacturers forecast equipment failures, reducing downtime and costs. (Example: PepsiCo's Frito-Lay plants saved costs and improved equipment performance)
# 2. **Generative Design**: AI-driven generative design enables manufacturers to quickly produce thousands of design options for a single product, improving innovation capacity. (Example: Airbus reduced aerodynamics prediction times from 1 hour to 30 milliseconds)
# 3. **Robotics**: Industrial robots, including cobots, automate repetitive tasks, prevent human error, and improve production efficiency. (Examples: BMW's Spartanburg plant saved $1 million yearly, Ford used cobots to sand car bodies)
# 4. **Quality Assurance**: AI-powered quality assurance systems detect defects and trigger alerts, ensuring consistent product quality. (Example: Samsung uses automated vehicles, robots, and mechanical arms for quality checks)
# 5. **Inventory Management**: AI-powered demand forecasting tools optimize inventory levels, reducing stockouts and overstocking.
# 6. **Process Optimization**: AI-powered process mining tools identify bottlenecks and optimize processes, improving efficiency and reducing costs. (Example: A manufacturer reduced deviations and maverick buying worth $60,000)
# 7. **Digital Twins**: AI-powered digital twins enable manufacturers to simulate and analyze production processes, improving product development, design customization, and logistics optimization. (Examples: Rolls-Royce improved predictive maintenance, Pfizer designed a Covid-19 drug in just 4 months)
# 8. **Edge Analytics**: Edge analytics provides fast and decentralized insights from machine data, reducing time to insight.
# 9. **Price Forecasting of Raw Materials**: AI-powered software predicts raw material prices, helping manufacturers adapt to price volatility.
# 10. **Logistics Optimization**: Digital twins enable manufacturers to gain a clear view of materials usage and automate replenishment processes.
#
# These applications of AI in manufacturing have numerous benefits, including improved efficiency, reduced costs, enhanced product quality, and increased safety.
#
# [4] Title: Key AI Applications In Manufacturing - Forbes
# Link: https://www.forbes.com/councils/forbestechcouncil/2025/04/17/key-ai-applications-in-manufacturing/
# Refined Content: Here is the extracted and synthesized information relevant to the research topic:
#
# **Key Applications of AI in Manufacturing:**
#
# 1. **Data Collection and Management**: AI tools are used for robust data acquisition, cleaning, and preparation from various sources, including sensors, equipment, automation, and control systems.
# 2. **Machine Learning (ML)**: ML is a cornerstone of AI in manufacturing, used to predict equipment failures, quality issues, and optimize equipment and manufacturing lines.
# 	* **Variations of ML:**
# 		+ Supervised learning: identifies good and bad data patterns to improve algorithm accuracy.
# 		+ Unsupervised learning: detects new data patterns without predefined examples.
# 		+ Reinforcement learning: used in adaptive control systems, allowing machines to learn through trial and error.
# 3. **Natural Language Processing (NLP)**: uses AI tools to analyze language, making results easy to understand, and presenting complex results in actionable ways.
# 4. **Generative AI**: beginning to have a significant impact in manufacturing, with future articles to focus on this topic.
#
# **Benefits of AI in Manufacturing:**
#
# * Reduces costs
# * Increases capabilities
# * Generates significant bottom-line returns
# * Improves data accuracy and context
# * Enables predictive maintenance and quality control
# * Optimizes equipment and manufacturing lines
#
# These key applications and benefits of AI in manufacturing highlight the significant impact of AI on the industry, with opportunities for further exploration and implementation.
#
# [5] Title: Adopting AI in manufacturing at speed and scale | McKinsey
# Link: https://www.mckinsey.com/capabilities/operations/our-insights/adopting-ai-at-s
#
# ...
#
#  Last 10000 characters of 6 results:
#
#   operational risks, skills shortages, cybersecurity concerns, change management, and implementation costs.
#
# [3] Title: Manufacturing AI: Top 15 tools & 13 real-life use cases ['25]
# Link: https://research.aimultiple.com/manufacturing-ai/
# Refined Content: **Key Applications of AI in the Manufacturing Industry**
#
# The manufacturing industry has widely adopted AI, with 93% of leaders stating their organizations are at least moderately using AI. The key applications of AI in manufacturing include:
#
# 1. **Predictive Maintenance**: AI-powered predictive maintenance helps manufacturers forecast equipment failures, reducing downtime and costs. (Example: PepsiCo's Frito-Lay plants saved costs and improved equipment performance)
# 2. **Generative Design**: AI-driven generative design enables manufacturers to quickly produce thousands of design options for a single product, improving innovation capacity. (Example: Airbus reduced aerodynamics prediction times from 1 hour to 30 milliseconds)
# 3. **Robotics**: Industrial robots, including cobots, automate repetitive tasks, prevent human error, and improve production efficiency. (Examples: BMW's Spartanburg plant saved $1 million yearly, Ford used cobots to sand car bodies)
# 4. **Quality Assurance**: AI-powered quality assurance systems detect defects and trigger alerts, ensuring consistent product quality. (Example: Samsung uses automated vehicles, robots, and mechanical arms for quality checks)
# 5. **Inventory Management**: AI-powered demand forecasting tools optimize inventory levels, reducing stockouts and overstocking.
# 6. **Process Optimization**: AI-powered process mining tools identify bottlenecks and optimize processes, improving efficiency and reducing costs. (Example: A manufacturer reduced deviations and maverick buying worth $60,000)
# 7. **Digital Twins**: AI-powered digital twins enable manufacturers to simulate and analyze production processes, improving product development, design customization, and logistics optimization. (Examples: Rolls-Royce improved predictive maintenance, Pfizer designed a Covid-19 drug in just 4 months)
# 8. **Edge Analytics**: Edge analytics provides fast and decentralized insights from machine data, reducing time to insight.
# 9. **Price Forecasting of Raw Materials**: AI-powered software predicts raw material prices, helping manufacturers adapt to price volatility.
# 10. **Logistics Optimization**: Digital twins enable manufacturers to gain a clear view of materials usage and automate replenishment processes.
#
# These applications of AI in manufacturing have numerous benefits, including improved efficiency, reduced costs, enhanced product quality, and increased safety.
#
# [4] Title: Key AI Applications In Manufacturing - Forbes
# Link: https://www.forbes.com/councils/forbestechcouncil/2025/04/17/key-ai-applications-in-manufacturing/
# Refined Content: Here is the extracted and synthesized information relevant to the research topic:
#
# **Key Applications of AI in Manufacturing:**
#
# 1. **Data Collection and Management**: AI tools are used for robust data acquisition, cleaning, and preparation from various sources, including sensors, equipment, automation, and control systems.
# 2. **Machine Learning (ML)**: ML is a cornerstone of AI in manufacturing, used to predict equipment failures, quality issues, and optimize equipment and manufacturing lines.
# 	* **Variations of ML:**
# 		+ Supervised learning: identifies good and bad data patterns to improve algorithm accuracy.
# 		+ Unsupervised learning: detects new data patterns without predefined examples.
# 		+ Reinforcement learning: used in adaptive control systems, allowing machines to learn through trial and error.
# 3. **Natural Language Processing (NLP)**: uses AI tools to analyze language, making results easy to understand, and presenting complex results in actionable ways.
# 4. **Generative AI**: beginning to have a significant impact in manufacturing, with future articles to focus on this topic.
#
# **Benefits of AI in Manufacturing:**
#
# * Reduces costs
# * Increases capabilities
# * Generates significant bottom-line returns
# * Improves data accuracy and context
# * Enables predictive maintenance and quality control
# * Optimizes equipment and manufacturing lines
#
# These key applications and benefits of AI in manufacturing highlight the significant impact of AI on the industry, with opportunities for further exploration and implementation.
#
# [5] Title: Adopting AI in manufacturing at speed and scale | McKinsey
# Link: https://www.mckinsey.com/capabilities/operations/our-insights/adopting-ai-at-speed-and-scale-the-4ir-push-to-stay-competitive
# Refined Content: Here is the extracted and synthesized information relevant to the research topic:
#
# **Evolution of AI Adoption in Manufacturing**
#
# The adoption of AI in manufacturing has evolved significantly over the past decade, with a notable acceleration in recent years. The Global Lighthouse Network, a World Economic Forum initiative, has identified 153 factories at the forefront of the Fourth Industrial Revolution (4IR). These "Lighthouses" have demonstrated a significant lead in AI adoption, with many having implemented AI use cases and achieved factory-scale adoption.
#
# **Key Developments**
#
# 1. **Maturity of AI**: AI technologies have reached unprecedented levels of maturity, enabling machines to perform complex tasks in the cyber-physical world of production.
# 2. **Scaling Impact**: Leading companies are redefining the concept of a pilot by using entire factories as pilots for network-wide deployment at scale.
# 3. **Gen AI**: Generative AI (Gen AI) has emerged as a new frontier, with the potential to add $2.6 trillion to $4.4 trillion in annual value to the global economy.
# 4. **Increased Speed and Scale**: Lighthouses have reduced the time to implement AI use cases, with 75% able to deploy new use cases in under six months, and 30% in under three months.
#
# **Changes in AI Adoption**
#
# 1. **From Piloting to Scaling**: Lighthouses have moved from piloting AI use cases to scaling impact across entire production networks.
# 2. **Increased Focus on Business Value**: Companies are now focusing on ensuring that every AI use case presents clear business value.
# 3. **Growing Performance Gap**: The performance gap between leaders and laggards is expanding, with Lighthouses achieving between two and three times ROI within three years and between four and five times ROI within five years.
#
# **Current State of AI in Manufacturing**
#
# 1. **AI as a Conductor**: AI is playing a crucial role in orchestrating complex technologies and enabling rapid solutions.
# 2. **Use Cases**: AI use cases are becoming increasingly prevalent, with over 60% of new Lighthouse applicants presenting AI-based use cases.
# 3. **Gen AI Adoption**: Nearly one-third of companies surveyed have implemented Gen AI in at least one business function.
#
# Overall, the adoption of AI in manufacturing has evolved significantly over the past decade, with a notable acceleration in recent years. Lighthouses have demonstrated leadership in AI adoption, and their experiences provide valuable insights for other manufacturers seeking to leverage AI for improved performance.
#
# [6] Title: AI in manufacturing: transforming the industry - alten.com
# Link: https://www.alten.com/ai-in-manufacturing-transforming-the-industry/
# Refined Content: **Evolution of AI Adoption in Manufacturing Over the Past Decade**
#
# The adoption of Artificial Intelligence (AI) in manufacturing has undergone significant evolution over the past decade, transforming from a futuristic concept to a practical reality. This evolution aligns with the Industry 4.0 movement, which integrates connected sensors, real-time data, and AI algorithms into manufacturing systems.
#
# **Key Developments:**
#
# 1. **From Traditional Automation to AI-Driven Systems**: The industry has shifted from traditional automation to AI-driven systems that continuously learn and improve without direct human intervention. This allows for greater flexibility, continuous process improvement, and the ability to respond to variable demands.
#
# 2. **Core AI Technologies**: Several core AI technologies have emerged as crucial in manufacturing, including:
#    - **Machine Learning**: Powers predictive maintenance, quality control, and process optimization by identifying patterns and anomalies in large datasets.
#    - **Natural Language Processing (NLP)**: Enhances supply chain efficiency by enabling human-machine interaction and analyzing unstructured data.
#    - **Computer Vision**: Boosts quality control with high-precision defect detection and visual inspection.
#    - **Digital Twin Technology**: Simulates and optimizes production lines in real-time, reducing downtime and improving efficiency.
#
# 3. **Real-World Applications and Benefits**: AI has been applied in various real-world manufacturing scenarios, including:
#    - **Predictive Maintenance**: A partnership between ALTEN and an Italian manufacturer resulted in a 2% reduction in defective products, extended machine lifespan, and lower energy consumption.
#    - **Generative AI**: ALTEN supported an industrial startup in integrating generative AI tools, achieving an 80% reduction in manual processing time, 93% accuracy in automatic drawing recognition, and 32% decrease in procurement costs.
#
# 4. **Structured Approach and Expert Support**: The successful adoption of AI in manufacturing requires a structured approach, clear use cases, and expert support. Companies like ALTEN provide tailored AI solutions and cross-sector experience to help manufacturers harness the full potential of AI.
#
# **Conclusion**: The adoption of AI in manufacturing has evolved significantly over the past decade, from a focus on traditional automation to the integration of advanced AI technologies that enable intelligent, adaptive, and efficient manufacturing systems. As AI continues to transform the industry, its applications are expected to expand, driving further innovation and competitiveness in the manufacturing sector.

# %% [markdown]
# ### STEP 3: Iterative Refinement - Addressing Information Gaps
#
# One of the most powerful aspects of our research pipeline is its ability to identify information gaps and adaptively refine the research process. Rather than relying solely on initial queries, the system:
#
# 1. Evaluates the completeness of currently gathered information
# 2. Identifies specific knowledge gaps related to the research topic
# 3. Generates targeted follow-up queries to fill those gaps
# 4. Iteratively expands the research until sufficient information is obtained
#
# **Disclaimer: This step involves multiple LLM runs processing long web texts, so we remind the user to be mindful about the resource management as defined at the beginning.**
#
# This iterative approach mimics how expert researchers work - continuously assessing what's known, what's missing, and how to fill those gaps systematically. Let's examine how this process works:

# %%
def conduct_iterative_research(topic: str, initial_results: SearchResults, all_queries: List[str],
                                  budget: int, max_queries: int, tavily_client: TavilyClient, together_client: Together,
                                  planning_model: str, json_model: str, summary_model: str, prompts: dict) -> tuple[SearchResults, List[str]]:
  """
  Conduct iterative research within budget to refine results.

  Args:
      topic: The research topic
      initial_results: Results from initial search
      all_queries: List of all queries used so far
      budget: Maximum number of follow-up iterations
      max_queries: Maximum number of queries to use per iteration
      tavily_client: The Tavily client for web search
      together_client: The Together AI client for LLM operations
      planning_model: Model to use for evaluation
      json_model: Model to use for JSON parsing
      summary_model: Model to use for summarization
      prompts: Dictionary of prompt templates

  Returns:
      Tuple of (final results, all queries used)
  """
  results = initial_results

  for _ in range(0, budget):
      # Evaluate if more research is needed using the independent function
      additional_queries = evaluate_research_completeness(
          topic, results, all_queries, together_client, planning_model, json_model, prompts
      )

      # Exit if research is complete
      if not additional_queries:
          print("No need for additional research")
          break

      # Limit the number of queries if needed
      if max_queries > 0:
          additional_queries = additional_queries[:max_queries]
      print("================================================\n\n")
      print(f"Additional queries from evaluation parser: {additional_queries}\n\n")
      print("================================================\n\n")

      # Expand research with new queries
      new_results = perform_search(
          additional_queries,
          tavily_client,
          prompts,
          together_client,
          summary_model
      )

      results = results + new_results
      all_queries.extend(additional_queries)

  return results, all_queries

def evaluate_research_completeness(topic: str, results: SearchResults, queries: List[str],
                                       together_client: Together, planning_model: str, json_model: str, prompts: dict) -> list[str]:
  """
  Evaluate if the current search results are sufficient or if more research is needed.

  Args:
      topic: The research topic
      results: Current search results
      queries: List of queries already used
      together_client: The Together AI client for LLM operations
      planning_model: Model to use for evaluation
      json_model: Model to use for JSON parsing
      prompts: Dictionary of prompt templates

  Returns:
      List of additional queries needed or empty list if research is complete
  """
  # Format the search results for the LLM
  formatted_results = str(results)

  EVALUATION_PROMPT = prompts["evaluation_prompt"]

  evaluation_response = together_client.chat.completions.create(
      model=planning_model,
      messages=[
          {"role": "system", "content": EVALUATION_PROMPT},
          {"role": "user", "content": (
              f"<Research Topic>{topic}</Research Topic>\n\n"
              f"<Search Queries Used>{queries}</Search Queries Used>\n\n"
              f"<Current Search Results>{formatted_results}</Current Search Results>"
          )}
      ]
  )
  evaluation = evaluation_response.choices[0].message.content

  print("================================================\n\n")
  print(f"Evaluation:\n\n {evaluation}")

  EVALUATION_PARSING_PROMPT = prompts["evaluation_parsing_prompt"]

  json_response = together_client.chat.completions.create(
      model=json_model,
      messages=[
          {"role": "system", "content": EVALUATION_PARSING_PROMPT},
          {"role": "user", "content": f"Evaluation to be parsed: {evaluation}"}
      ],
      response_format={"type": "json_object", "schema": ResearchPlan.model_json_schema()}
  )

  response_json = json_response.choices[0].message.content
  evaluation = json.loads(response_json)
  return evaluation["queries"]

# %%
results, all_queries=conduct_iterative_research(topic=research_topic, initial_results=initial_results, all_queries=initial_queries, budget=budget, max_queries=max_queries, tavily_client=sync_tavily_client, together_client=sync_together_client, planning_model=planning_model, json_model=json_model, summary_model=summary_model, prompts=prompts)
# Out:
# ================================================
#
#
# Evaluation:
#
#  ### Analysis of Search Results Against the Original Research Goal
#
# **Research Goal:** To understand the impact of artificial intelligence (AI) on the manufacturing industry, including key applications, evolution over the past decade, and any significant challenges or benefits.
#
# ### Key Findings from Current Search Results
#
# 1. **Key Applications of AI in Manufacturing:**
#    - **Predictive Maintenance**: Reduces unexpected downtime and maintenance costs.
#    - **Quality Control**: Enhances product quality and reduces waste.
#    - **Supply Chain and Inventory Optimization**: Improves demand forecasting and inventory management.
#    - **Process Optimization**: Enhances efficiency and reduces costs.
#    - **Production Line Automation and Robotics**: Increases productivity and precision.
#    - **Digital Twin Technology**: Simulates and optimizes production processes.
#    - **Worker Safety and Hazard Detection**: Enhances workplace safety.
#    - **Energy Efficiency**: Reduces energy consumption and costs.
#    - **Generative Design**: Accelerates the design cycle and innovation.
#    - **Workforce Management**: Optimizes employee scheduling and productivity.
#    - **Custom Manufacturing**: Enables mass customization.
#
# 2. **Evolution of AI Adoption Over the Past Decade:**
#    - **Maturity of AI**: AI technologies have become more mature and capable.
#    - **Scaling Impact**: Leading companies are moving from piloting to scaling AI use cases across entire production networks.
#    - **Increased Speed and Scale**: Faster deployment of AI use cases, with many companies achieving significant ROI within a few years.
#    - **Gen AI**: Emergence of generative AI as a new frontier with significant economic potential.
#    - **From Traditional Automation to AI-Driven Systems**: Shift from traditional automation to AI-driven systems that continuously learn and improve.
#
# 3. **Benefits of AI in Manufacturing:**
#    - **Cost Reduction**: Reduces maintenance costs, inventory carrying costs, and energy consumption.
#    - **Increased Efficiency**: Enhances productivity and reduces downtime.
#    - **Improved Quality**: Enhances product quality and reduces defects.
#    - **Enhanced Safety**: Improves worker safety and reduces workplace hazards.
#    - **Innovation and Competitive Advantage**: Drives innovation and helps companies stay competitive.
#
# 4. **Challenges of AI in Manufacturing:**
#    - **Data Quality and Availability**: Ensuring high-quality data for AI models.
#    - **Operational Risks**: Managing risks associated with AI implementation.
#    - **Skills Shortages**: Lack of skilled personnel to implement and manage AI systems.
#    - **Cybersecurity Concerns**: Protecting AI systems from cyber threats.
#    - **Change Management**: Overcoming resistance to change and ensuring smooth adoption.
#    - **Implementation Costs**: High initial costs for AI implementation.
#
# ### Identified Information Gaps
#
# 1. **Quantitative Data on ROI and Cost Savings:**
#    - **Gap**: While the benefits of AI are mentioned, there is a lack of specific quantitative data on return on investment (ROI) and cost savings for different AI applications.
#    - **Follow-up Query**: "What are the specific ROI and cost savings achieved by manufacturers who have implemented AI in their operations?"
#
# 2. **Case Studies and Real-World Examples:**
#    - **Gap**: While some examples are provided, there is a need for more detailed case studies and real-world examples to illustrate the impact of AI in different manufacturing sectors.
#    - **Follow-up Query**: "Provide detailed case studies of manufacturers who have successfully implemented AI and the specific outcomes achieved."
#
# 3. **Long-Term Impact and Sustainability:**
#    - **Gap**: The long-term impact of AI on the manufacturing industry, including sustainability and environmental benefits, is not thoroughly covered.
#    - **Follow-up Query**: "What are the long-term impacts of AI on the manufacturing industry, including sustainability and environmental benefits?"
#
# 4. **Regulatory and Ethical Considerations:**
#    - **Gap**: There is limited information on the regulatory and ethical considerations surrounding the use of AI in manufacturing.
#    - **Follow-up Query**: "What are the regulatory and ethical considerations for the use of AI in the manufacturing industry?"
#
# 5. **Future Trends and Predictions:**
#    - **Gap**: While the current state and recent developments are discussed, there is a lack of information on future trends and predictions for AI in manufacturing.
#    - **Follow-up Query**: "What are the future trends and predictions for the use of AI in the manufacturing industry over the next 5-10 years?"
#
# ### Conclusion
#
# The current search results provide a comprehensive overview of the key applications, evolution, benefits, and challenges of AI in the manufacturing industry. However, there are specific information gaps that need to be addressed to complete the research. The identified gaps and targeted follow-up queries will help fill these gaps and provide a more holistic understanding of the impact of AI on the manufacturing industry.
# ================================================
#
#
# Additional queries from evaluation parser: ['What are the specific ROI and cost savings achieved by manufacturers who have implemented AI in their operations?', 'Provide detailed case studies of manufacturers who have successfully implemented AI and the specific outcomes achieved.']
#
#
# ================================================
#
#
# Performing search for 2 queries
# Perform Tavily search with query: What are the specific ROI and cost savings achieved by manufacturers who have implemented AI in their operations?
# Tavily Responded with 5 results (Tavily returning None will be ignored for summarization)
# Before summarize_content async
# Summarizing content asynchronously using the LLM
# Returning LLM response
# After summarize_content async
# Before summarize_content async
# Summarizing content asynchronously using the LLM
# Returning LLM response
# After summarize_content async
# Before summarize_content async
# Summarizing content asynchronously using the LLM
# Returning LLM response
# After summarize_content async
# Before gathering
# After gathering
# Perform Tavily search with query: Provide detailed case studies of manufacturers who have successfully implemented AI and the specific outcomes achieved.
# Tavily Responded with 5 results (Tavily returning None will be ignored for summarization)
# Before summarize_content async
# Summarizing content asynchronously using the LLM
# Returning LLM response
# After summarize_content async
# Before summarize_content async
# Summarizing content asynchronously using the LLM
# Returning LLM response
# After summarize_content async
# Before summarize_content async
# Summarizing content asynchronously using the LLM
# Returning LLM response
# After summarize_content async
# Before summarize_content async
# Summarizing content asynchronously using the LLM
# Returning LLM response
# After summarize_content async
# Before gathering
# After gathering
# Search complete, found 7 results after deduplication
# ================================================
#
#
# Evaluation:
#
#  ### Analysis of Search Results and Identification of Information Gaps
#
# #### Overview of Current Findings
# The current search results provide a comprehensive overview of the impact of artificial intelligence (AI) on the manufacturing industry. The key areas covered include:
#
# 1. **Key Applications of AI in Manufacturing**:
#    - Predictive maintenance
#    - Quality control and defect detection
#    - Supply chain and inventory optimization
#    - Process optimization and waste reduction
#    - Production line automation and robotics integration
#    - Digital twin technology
#    - Worker safety and hazard detection
#    - Energy efficiency and smart resource management
#
# 2. **Evolution of AI Adoption**:
#    - Shift from traditional automation to AI-driven systems
#    - Maturity of AI technologies
#    - Scaling impact and increased focus on business value
#    - Growing performance gap between leaders and laggards
#
# 3. **Specific ROI and Cost Savings**:
#    - 38% increase in profit margins
#    - 30% reduction in downtime
#    - 20% reduction in energy consumption
#    - 25% improvement in defect detection rates
#    - 90% defect detection accuracy
#
# 4. **Case Studies**:
#    - Detailed case studies from Siemens, General Electric, Toyota, Boeing, Intel, Nissan, Harley-Davidson, ABB, LG Electronics, Honda, BASF, Samsung, Volvo, Caterpillar, and Philips
#    - Specific outcomes such as increased productivity, reduced downtime, improved quality, and cost savings
#
# #### Identified Information Gaps
#
# 1. **Detailed Implementation Strategies**:
#    - **Gap**: While the case studies provide high-level outcomes, there is a lack of detailed information on the specific strategies and steps taken by manufacturers to implement AI successfully.
#    - **Follow-up Query**: "What are the detailed implementation strategies and best practices for integrating AI in manufacturing operations?"
#
# 2. **Challenges and Barriers**:
#    - **Gap**: The current results mention some challenges, such as data quality and operational risks, but do not provide a comprehensive list of common challenges and barriers to AI adoption in manufacturing.
#    - **Follow-up Query**: "What are the common challenges and barriers to AI adoption in the manufacturing industry, and how can they be overcome?"
#
# 3. **Long-term Impact and Sustainability**:
#    - **Gap**: There is limited information on the long-term impact of AI on the manufacturing industry, including sustainability and environmental benefits.
#    - **Follow-up Query**: "What are the long-term impacts of AI on the manufacturing industry, including sustainability and environmental benefits?"
#
# 4. **Workforce Impact and Training**:
#    - **Gap**: The current results do not provide detailed information on how AI adoption affects the workforce, including job displacement, reskilling, and upskilling needs.
#    - **Follow-up Query**: "How does the adoption of AI in manufacturing impact the workforce, and what are the necessary training and reskilling programs?"
#
# 5. **Regulatory and Ethical Considerations**:
#    - **Gap**: There is a lack of information on the regulatory and ethical considerations associated with AI in manufacturing, including data privacy, security, and ethical use of AI.
#    - **Follow-up Query**: "What are the regulatory and ethical considerations for the use of AI in manufacturing, and how are they being addressed?"
#
# 6. **Comparative Analysis**:
#    - **Gap**: The current results do not provide a comparative analysis of AI adoption across different regions or industries within manufacturing.
#    - **Follow-up Query**: "How does AI adoption in manufacturing vary across different regions and industries, and what are the key differences in implementation and outcomes?"
#
# #### Conclusion
# While the current search results provide a robust foundation for understanding the impact of AI on the manufacturing industry, there are several specific information gaps that need to be addressed to complete the research. The identified gaps and follow-up queries will help in gathering more detailed and comprehensive information, ensuring a well-rounded and thorough analysis of the topic.
# ================================================
#
#
# Additional queries from evaluation parser: ['What are the detailed implementation strategies and best practices for integrating AI in manufacturing operations?', 'What are the common challenges and barriers to AI adoption in the manufacturing industry, and how can they be overcome?']
#
#
# ================================================
#
#
# Performing search for 2 queries
# Perform Tavily search with query: What are the detailed implementation strategies and best practices for integrating AI in manufacturing operations?
# Tavily Responded with 5 results (Tavily returning None will be ignored for summarization)
# Before summarize_content async
# Summarizing content asynchronously using the LLM
# Returning LLM response
# After summarize_content async
# Before summarize_content async
# Summarizing content asynchronously using the LLM
# Returning LLM response
# After summarize_content async
# Before summarize_content async
# Summarizing content asynchronously using the LLM
# Returning LLM response
# After summarize_content async
# Before summarize_content async
# Summarizing content asynchronously using the LLM
# Returning LLM response
# After summarize_content async
# Before summarize_content async
# Summarizing content asynchronously using the LLM
# Returning LLM response
# After summarize_content async
# Before gathering
# After gathering
# Perform Tavily search with query: What are the common challenges and barriers to AI adoption in the manufacturing industry, and how can they be overcome?
# Tavily Responded with 5 results (Tavily returning None will be ignored for summarization)
# Before summarize_content async
# Summarizing content asynchronously using the LLM
# Returning LLM response
# After summarize_content async
# Before summarize_content async
# Summarizing content asynchronously using the LLM
# Returning LLM response
# After summarize_content async
# Before summarize_content async
# Summarizing content asynchronously using the LLM
# Returning LLM response
# After summarize_content async
# Before gathering
# After gathering
# Search complete, found 8 results after deduplication

# %% [markdown]
# Below is the comprehensive collection of all queries executed and results gathered throughout our research process. This dataset represents:
#
# 1. Initial queries generated from the research topic
# 2. Follow-up queries identified through gap analysis
# 3. All retrieved content after preprocessing and relevance filtering
# 4. Source metadata for proper attribution
#
# This consolidated view demonstrates the breadth and depth of information our system has gathered, providing the foundation for our final research synthesis:

# %%
all_queries
# Out:
# ['What are the key applications of AI in the manufacturing industry?',
#  'How has the adoption of AI in manufacturing evolved over the past decade?',
#  'What are the specific ROI and cost savings achieved by manufacturers who have implemented AI in their operations?',
#  'Provide detailed case studies of manufacturers who have successfully implemented AI and the specific outcomes achieved.',
#  'What are the detailed implementation strategies and best practices for integrating AI in manufacturing operations?',
#  'What are the common challenges and barriers to AI adoption in the manufacturing industry, and how can they be overcome?']

# %%
print(f"First 10000 characters of {len(results.results)} results:\n\n {str(results)[:10000]}\n\n...\n\n Last 10000 characters of {len(results.results)} results:\n\n {str(results)[-10000:]}\n\n")
# Out:
# First 10000 characters of 21 results:
#
#  [1] Title: AI in Manufacturing : Key Use Cases and benefits for 2025 and Beyond
# Link: https://www.softlabsgroup.com/blogs/ai-in-manufacturing/
# Refined Content: Here are the key applications of AI in the manufacturing industry:
#
# 1. **Predictive Maintenance & Equipment Health Monitoring**: AI detects early signs of equipment failure, reducing unexpected downtime and extending machine life.
# 2. **Automated Quality Inspection & Defect Detection**: AI-powered vision systems analyze production lines in real-time to detect defects and anomalies.
# 3. **Supply Chain & Inventory Optimization**: AI-driven demand forecasting helps manufacturers maintain optimal inventory levels, reducing overstocking and material shortages.
# 4. **Process Optimization & Waste Reduction**: AI continuously analyzes production data to optimize workflows, energy consumption, and material usage.
# 5. **Production Line Automation & Robotics Integration**: AI enables robotic systems to handle complex assembly, packaging, and material movement tasks with precision.
# 6. **Digital Twin for Manufacturing Simulation**: AI-powered digital twins create virtual replicas of production facilities, allowing manufacturers to test changes and predict performance outcomes.
# 7. **Worker Safety & Hazard Detection**: AI monitors workplace conditions and worker activity to detect safety risks, such as exposure to hazardous materials or unsafe equipment handling.
# 8. **Energy Efficiency & Smart Resource Management**: AI optimizes energy consumption by analyzing usage patterns and adjusting operations accordingly.
#
# **Top Use Cases of AI in Manufacturing:**
#
# 1. **AI-Powered Inventory Optimization**: AI-driven inventory management systems continuously monitor stock levels in real-time, predict demand fluctuations, and automate restocking processes.
# 2. **AI-Driven Production Monitoring**: AI-powered production tracking systems analyze real-time sensor data from machines to detect anomalies, optimize workflows, and enhance productivity.
# 3. **PPE Compliance Monitoring for Worker Safety**: AI-powered computer vision systems monitor workers in real-time to detect whether they are wearing required safety gear.
# 4. **AI-Enabled Load Security Monitoring**: AI-powered monitoring systems analyze vehicle loads in real-time, ensuring they are properly secured before transportation.
# 5. **AI-Powered Vehicle Identification for Secure Logistics**: AI-powered vehicle recognition systems use computer vision and real-time data processing to authenticate vehicle make, model, and license plates.
# 6. **AI-Driven Fleet Optimization for Manufacturing Logistics**: AI-driven fleet management systems analyze real-time GPS data, traffic patterns, and vehicle conditions to optimize routes, predict maintenance needs, and reduce idle times.
#
# These applications and use cases demonstrate the significant impact of AI on the manufacturing industry, from improving efficiency and productivity to enhancing quality control and worker safety.
#
# [2] Title: How is AI being used in Manufacturing | IBM
# Link: https://www.ibm.com/think/topics/ai-in-manufacturing
# Refined Content: **Key Applications of AI in Manufacturing**
#
# Artificial intelligence (AI) is transforming the manufacturing industry by enhancing efficiency, precision, and adaptability in various production processes. The key applications of AI in manufacturing include:
#
# 1. **Predictive Maintenance**: AI analyzes sensor data from machinery to forecast failures before they occur, reducing unexpected downtimes and maintenance costs.
# 2. **Quality Control**: AI-powered computer vision systems scan products in real-time to identify defects, improving product quality and reducing waste.
# 3. **Digital Twin Technology**: AI creates virtual replicas of processes, production lines, factories, and supply chains to simulate, analyze, and predict performance in real-time.
# 4. **Collaborative Robots (Cobots)**: AI-powered cobots work safely alongside humans, handling repetitive or physically demanding tasks and enhancing productivity and safety.
# 5. **Generative Design**: AI-driven generative design technology explores a wide array of design options based on parameters such as materials and manufacturing constraints, accelerating the design cycle.
# 6. **Supply Chain Management**: AI optimizes supply chains by analyzing vast datasets to predict demand, manage inventory, and streamline logistics.
# 7. **Inventory Management**: AI optimizes inventory levels by analyzing data to predict stock needs and automate replenishment, reducing carrying costs and improving cash flow.
# 8. **Energy Management**: AI systems monitor energy usage in real-time to identify inefficiencies and recommend adjustments that reduce energy costs and minimize environmental impact.
# 9. **Workforce Management**: AI aids in workforce planning and management by analyzing employee data to optimize shifts and improve productivity.
# 10. **Custom Manufacturing**: AI enables manufacturers to offer mass customization, allowing products to be tailored to individual customer preferences without slowing down production.
#
# These applications of AI in manufacturing are driving significant benefits, including:
#
# * Increased efficiency
# * Cost reduction
# * Improved decision-making
# * Increased safety
# * Sustainability
# * Innovation and competitive advantage
#
# However, there are also challenges associated with using AI in manufacturing, including data quality and availability, operational risks, skills shortages, cybersecurity concerns, change management, and implementation costs.
#
# [3] Title: Manufacturing AI: Top 15 tools & 13 real-life use cases ['25]
# Link: https://research.aimultiple.com/manufacturing-ai/
# Refined Content: **Key Applications of AI in the Manufacturing Industry**
#
# The manufacturing industry has widely adopted AI, with 93% of leaders stating their organizations are at least moderately using AI. The key applications of AI in manufacturing include:
#
# 1. **Predictive Maintenance**: AI-powered predictive maintenance helps manufacturers forecast equipment failures, reducing downtime and costs. (Example: PepsiCo's Frito-Lay plants saved costs and improved equipment performance)
# 2. **Generative Design**: AI-driven generative design enables manufacturers to quickly produce thousands of design options for a single product, improving innovation capacity. (Example: Airbus reduced aerodynamics prediction times from 1 hour to 30 milliseconds)
# 3. **Robotics**: Industrial robots, including cobots, automate repetitive tasks, prevent human error, and improve production efficiency. (Examples: BMW's Spartanburg plant saved $1 million yearly, Ford used cobots to sand car bodies)
# 4. **Quality Assurance**: AI-powered quality assurance systems detect defects and trigger alerts, ensuring consistent product quality. (Example: Samsung uses automated vehicles, robots, and mechanical arms for quality checks)
# 5. **Inventory Management**: AI-powered demand forecasting tools optimize inventory levels, reducing stockouts and overstocking.
# 6. **Process Optimization**: AI-powered process mining tools identify bottlenecks and optimize processes, improving efficiency and reducing costs. (Example: A manufacturer reduced deviations and maverick buying worth $60,000)
# 7. **Digital Twins**: AI-powered digital twins enable manufacturers to simulate and analyze production processes, improving product development, design customization, and logistics optimization. (Examples: Rolls-Royce improved predictive maintenance, Pfizer designed a Covid-19 drug in just 4 months)
# 8. **Edge Analytics**: Edge analytics provides fast and decentralized insights from machine data, reducing time to insight.
# 9. **Price Forecasting of Raw Materials**: AI-powered software predicts raw material prices, helping manufacturers adapt to price volatility.
# 10. **Logistics Optimization**: Digital twins enable manufacturers to gain a clear view of materials usage and automate replenishment processes.
#
# These applications of AI in manufacturing have numerous benefits, including improved efficiency, reduced costs, enhanced product quality, and increased safety.
#
# [4] Title: Key AI Applications In Manufacturing - Forbes
# Link: https://www.forbes.com/councils/forbestechcouncil/2025/04/17/key-ai-applications-in-manufacturing/
# Refined Content: Here is the extracted and synthesized information relevant to the research topic:
#
# **Key Applications of AI in Manufacturing:**
#
# 1. **Data Collection and Management**: AI tools are used for robust data acquisition, cleaning, and preparation from various sources, including sensors, equipment, automation, and control systems.
# 2. **Machine Learning (ML)**: ML is a cornerstone of AI in manufacturing, used to predict equipment failures, quality issues, and optimize equipment and manufacturing lines.
# 	* **Variations of ML:**
# 		+ Supervised learning: identifies good and bad data patterns to improve algorithm accuracy.
# 		+ Unsupervised learning: detects new data patterns without predefined examples.
# 		+ Reinforcement learning: used in adaptive control systems, allowing machines to learn through trial and error.
# 3. **Natural Language Processing (NLP)**: uses AI tools to analyze language, making results easy to understand, and presenting complex results in actionable ways.
# 4. **Generative AI**: beginning to have a significant impact in manufacturing, with future articles to focus on this topic.
#
# **Benefits of AI in Manufacturing:**
#
# * Reduces costs
# * Increases capabilities
# * Generates significant bottom-line returns
# * Improves data accuracy and context
# * Enables predictive maintenance and quality control
# * Optimizes equipment and manufacturing lines
#
# These key applications and benefits of AI in manufacturing highlight the significant impact of AI on the industry, with opportunities for further exploration and implementation.
#
# [5] Title: Adopting AI in manufacturing at speed and scale | McKinsey
# Link: https://www.mckinsey.com/capabilities/operations/our-insights/adopting-ai-at-s
#
# ...
#
#  Last 10000 characters of 21 results:
#
#  *Best Practice:** Embrace sustainable practices across the entire value chain, from sourcing raw materials to minimizing waste and reducing carbon footprint.
#
# ### 5. **Unlocking Holistic Insights**
#
# * **Implementation Strategy:** Integrate data from disparate departments and systems using a unified data and AI layer (e.g., Manufacturing Data Engine).
# * **Best Practice:** Establish interoperability across OT, IT, and ET data to unlock the full potential of AI and drive informed business decisions.
#
# **Additional Best Practices:**
#
# * **Data Integration:** Establish a digital thread by connecting data back to its source, ensuring traceability and a holistic understanding of the product lifecycle.
# * **Security:** Implement AI-powered security to detect anomalies, facilitate threat intelligence, and ensure data integrity across interconnected systems.
# * **Collaboration:** Leverage partnerships and collaborations (e.g., Google Cloud Next, Hannover Messe) to stay updated on the latest advancements in data and AI platforms.
#
# **Tools and Technologies:**
#
# * **Manufacturing Data Engine (MDE):** A unified data and AI layer that facilitates the analysis of multimodal data for better supply chain visibility, supports assistive search for bridging talent gaps, and enables AI agents to optimize sustainability initiatives.
# * **Cortex Framework:** Allows for the seamless integration of enterprise data with manufacturing data, enabling use cases like forecasting financial impact with machine data and optimizing production schedules based on demand signals.
#
# [19] Title: Top 5 AI Adoption Challenges for 2025: Overcoming Barriers to Success
# Link: https://convergetp.com/2025/03/25/top-5-ai-adoption-challenges-for-2025-overcoming-barriers-to-success/
# Refined Content: Based on the provided content, the common challenges and barriers to AI adoption are discussed in a general context, but the specific industry of manufacturing is not explicitly mentioned. However, the challenges and solutions can be related to the manufacturing industry. Here are the extracted and synthesized relevant information:
#
# **Common Challenges and Barriers to AI Adoption:**
#
# 1. **Data Quality, Availability, and Bias**: AI models require high-quality data to produce reliable insights. In manufacturing, this can be a challenge due to legacy systems, siloed data, or limited access to diverse data.
# 2. **Privacy and Security**: Manufacturing organizations must ensure the secure handling of sensitive data, such as proprietary business information and customer records.
# 3. **IT Infrastructure Integration**: Integrating AI systems with existing IT infrastructure can be complex, especially in manufacturing environments with legacy systems.
# 4. **Financial Justification**: AI projects require significant upfront costs, and the return on investment (ROI) may not be immediate, making it challenging to justify the investment.
# 5. **In-House Expertise**: Manufacturing organizations may face a shortage of skilled professionals with expertise in AI development, deployment, and maintenance.
#
# **Overcoming Barriers to AI Adoption:**
#
# 1. **Prioritize Governance, Transparency, and Ethics**: Establish strong governance frameworks to ensure AI is used responsibly and ethically.
# 2. **Enhance Data Management Practices**: Adopt advanced data management techniques, such as anonymization, differential privacy, and encryption.
# 3. **Identify the Right Mix of Solutions**: Assess unique needs and infrastructure readiness to select the right combination of tools, platforms, and deployment models.
# 4. **Craft a Compelling Case for Investment**: Align AI with business objectives, quantify expected ROI, and highlight competitive advantages.
# 5. **Find the Right AI Partner**: Collaborate with a trusted AI partner that brings strategic insight, industry-specific expertise, and a proven track record of success.
#
# While the content does not specifically focus on the manufacturing industry, these challenges and solutions can be applied to the industry. Manufacturers can leverage these insights to overcome common barriers to AI adoption and successfully integrate AI into their operations.
#
# [20] Title: Unlocking AI's Potential: Overcoming Barriers To Adoption - Forbes
# Link: https://www.forbes.com/councils/forbestechcouncil/2025/02/21/unlocking-ais-potential-overcoming-barriers-to-adoption/
# Refined Content: Based on the provided content, the following information is relevant to the research topic:
#
# **Common challenges and barriers to AI adoption:**
#
# 1. **Data challenges**: Poor data quality, unstructured formats, low accuracy, and insufficient meta-tagging.
# 2. **Data silos**: Organizational politics leading to fragmentation and stifling collaboration across departments.
# 3. **Data privacy and ethics**: Concerns around data privacy and ethics, including the risk of exposing personally identifiable information (PII).
# 4. **Resistance to change**: Human factors, including fear of job displacement and lack of understanding.
# 5. **Insufficient leadership support**: Lack of leadership trust in AI tools and risk aversion.
# 6. **Skills gap**: Limited expertise in AI and data science.
# 7. **Identifying effective use cases**: Prioritizing technology over business needs and making unvalidated assumptions about customer pain points.
#
# **Strategies to overcome these barriers:**
#
# 1. **Address data challenges**: Invest in data cleaning and integration tools, and implement robust data governance frameworks.
# 2. **Foster a culture of innovation and experimentation**: Encourage experimentation, provide training and upskilling opportunities, and recognize and reward innovation.
# 3. **Ensure leadership support**: Secure executive sponsorship, lead by example, and demonstrate the potential of AI.
# 4. **Bridge the skills gap**: Upskill the workforce, leverage no-code or low-code AI platforms, and encourage collaboration between AI specialists and domain experts.
# 5. **Identify effective use cases**: Use approaches like Amazon's "Working Backwards" methodology to validate problems and ensure solutions meet real business needs.
#
# **While the content does not specifically focus on the manufacturing industry, the challenges and strategies mentioned can be applied to this industry as well.**
#
# Some specific considerations for the manufacturing industry:
#
# * **Data challenges**: Manufacturing organizations may face unique data challenges, such as integrating data from disparate sources (e.g., sensors, machines, and production systems).
# * **Use cases**: Effective use cases in manufacturing may include predictive maintenance, quality control, and supply chain optimization.
# * **Skills gap**: Manufacturing organizations may need to upskill workers to work with AI and data analytics tools, and to interpret data insights to inform production decisions.
#
# By understanding these common challenges and strategies, manufacturing organizations can better navigate the adoption of AI and unlock its potential to drive innovation and growth.
#
# [21] Title: Beyond The Hype: Confronting And Conquering AI Adoption Challenges - Forbes
# Link: https://www.forbes.com/councils/forbestechcouncil/2025/04/16/beyond-the-hype-confronting-and-conquering-ai-adoption-challenges/
# Refined Content: Based on the provided content, the common challenges and barriers to AI adoption, which can be applied to the manufacturing industry, are:
#
# **Challenges and Barriers:**
#
# 1. **Lack of AI and Data Literacy**: Insufficient understanding and application of AI and data analysis across teams, including employees, product managers, and engineers.
# 2. **Resistance to Change**: Employees' fear of job loss, struggle with AI-driven workflows, and organizational resistance to adopting AI.
# 3. **Legal and Ethical Concerns**: Compliance with regulations (e.g., GDPR, DMA), managing biases, and ensuring transparency and accountability in AI decision-making.
# 4. **Resource Optimization**: High investment costs, inefficient resource allocation, and the need for a balanced approach to optimize costs and ensure financial sustainability.
#
# **Overcoming the Challenges:**
#
# 1. **Develop an AI-First Mindset**: Leadership should drive AI initiatives, set clear goals, and incorporate AI expertise in decision-making teams.
# 2. **Invest in AI Education**: Establish tailored learning programs for employees, focusing on role-specific AI knowledge and application.
# 3. **Encourage AI Experimentation**: Foster a culture of AI innovation through small-scale pilot programs, learning from failures, and iterating quickly.
# 4. **Ensure Responsible AI Development**: Establish clear governance frameworks, conduct regular audits, and enforce strict data privacy measures.
# 5. **Align AI Investments with Business Value**: Focus on cost-effective hardware usage, scalable infrastructure, and tangible business impact, prioritizing investments that yield measurable improvements.
#
# **Manufacturing Industry Considerations:**
#
# While the content does not specifically focus on the manufacturing industry, the challenges and solutions mentioned can be applied to this sector. To overcome AI adoption barriers, manufacturing companies can:
#
# 1. **Upskill and reskill employees**: Provide training on AI, data analysis, and interpretation to ensure a workforce capable of working with AI technologies.
# 2. **Implement AI in pilot projects**: Test AI solutions in specific areas, such as predictive maintenance or quality control, to demonstrate value and build confidence.
# 3. **Develop a clear AI strategy**: Align AI initiatives with business objectives, identify areas for improvement, and prioritize investments that drive measurable value.
# 4. **Address data management and security**: Ensure the availability, quality, and security of data used in AI applications, while complying with relevant regulations.
#
# By understanding these challenges and implementing strategies to overcome them, manufacturing companies can successfully adopt AI and harness its transformative power.

# %% [markdown]
# ### STEP 4: Content Filtering and Prioritization - Optimizing Information Quality
#
# After gathering comprehensive information through our iterative search process, we face a new challenge: not all content is equally valuable or relevant. This step addresses the critical task of quality control by:
#
# 1. Evaluating each source for relevance, credibility, and information value
# 2. Prioritizing the most pertinent content while filtering out noise
# 3. Organizing information to create an optimal foundation for synthesis
#
# This filtering process improves the quality of our final research output by ensuring we synthesize only the most valuable information. The system acts as a discerning research assistant, making informed judgments about which sources deserve attention:

# %%
def filter_results(topic: str, results: SearchResults, together_client: Together, json_model: str, max_sources: int, prompts: dict) -> tuple[SearchResults, SourceList]:
  """
  Filter and rank search results based on relevance to the research topic.

  Args:
      topic: The research topic
      results: Search results to filter
      together_client: The Together AI client for LLM operations
      json_model: Model to use for filtering
      max_sources: Maximum number of sources to keep (-1 for unlimited)
      prompts: Dictionary of prompt templates

  Returns:
      Tuple of (filtered results, source list with indices)
  """
  # Format the search results for the LLM, without the raw content
  formatted_results = results.short_str()

  FILTER_PROMPT = prompts["filter_prompt"]

  SOURCE_PARSING_PROMPT = prompts['source_parsing_prompt']

  llm_filter_response = together_client.chat.completions.create(
      model=json_model,
      messages=[
          {"role": "system", "content": FILTER_PROMPT},
          {"role": "user", "content": (
              f"<Research Topic>{topic}</Research Topic>\n\n"
              f"<Current Search Results>{formatted_results}</Current Search Results>"
          )}
      ]
  )

  llm_filter_response_content = llm_filter_response.choices[0].message.content
  print(f'filter response: {llm_filter_response_content}')

  json_response = together_client.chat.completions.create(
      model=json_model,
      messages=[
          {"role": "system", "content": SOURCE_PARSING_PROMPT},
          {"role": "user", "content": f"<FILTER_RESPONSE>{llm_filter_response_content}</FILTER_RESPONSE>"}
      ],
      response_format={"type": "json_object", "schema": SourceList.model_json_schema()}
  )

  response_json = json_response.choices[0].message.content
  evaluation = json.loads(response_json)
  sources = evaluation["sources"]

  print(f'sources ranked by relevance {sources} (we will keep maximum of {max_sources} sources, as defined by the user)')

  if max_sources > 0:
      sources = sources[:max_sources]

  # Filter the results based on the source list
  filtered_results = [results.results[i] for i in sources if i < len(results.results)]

  return SearchResults(filtered_results), sources

def process_search_results(topic: str, results: SearchResults, together_client: Together, json_model: str, max_sources: int, prompts: dict) -> SearchResults:
  """Step 4: Process search results by deduplicating and filtering"""
  # Deduplicate results
  results = results.dedup()
  print(f"Deduplication complete, kept {len(results.results)} results")

  # Filter results
  filtered_results, sources = filter_results(topic, results, together_client, json_model, max_sources, prompts)
  print(f"LLM Filtering complete, kept {len(filtered_results.results)} results")

  return filtered_results

# %% [markdown]
# **Note: In rare cases we saw none results were kept after LLM filtering, where rerunning the cell would typically resolve the issue.**

# %%
processed_results=process_search_results(research_topic, results, sync_together_client, json_model, max_sources, prompts)
# Out:
# Deduplication complete, kept 20 results
# filter response: Based on the provided search results, I have evaluated each result for relevance, accuracy, and information value related to the research topic "The impact of artificial intelligence on the manufacturing industry." Here's the evaluation:
#
# **Relevant Results:**
#
# 1. [2] Title: How is AI being used in Manufacturing | IBM - This article provides a comprehensive overview of AI applications in manufacturing, including its benefits and challenges.
# 2. [3] Title: Manufacturing AI: Top 15 tools & 13 real-life use cases ['25] - This article lists various AI tools and use cases in manufacturing, providing insights into the current state of AI adoption in the industry.
# 3. [4] Title: Key AI Applications In Manufacturing - Forbes - This article highlights specific AI applications in manufacturing, including data collection, predictive maintenance, and quality control.
# 4. [5] Title: Adopting AI in manufacturing at speed and scale | McKinsey - This article discusses the importance of adopting AI in manufacturing and provides guidance on how to do so effectively.
# 5. [7] Title: Stats & Impact of AI in Manufacturing [2025] - This article provides statistics and insights into the impact of AI on manufacturing, including its benefits and challenges.
# 6. [10] Title: How can AI be Used in Manufacturing? [15 Case Studies] [2025] - This article presents 15 case studies of AI adoption in manufacturing, providing real-world examples of AI applications.
# 7. [14] Title: AI in Manufacturing in 2025: Transforming the Future of Industry - This article explores the impact of AI on manufacturing, including its benefits, challenges, and future trends.
# 8. [15] Title: Best Practices For AI In Manufacturing: Expanding Human Potential - Forbes - This article provides best practices for AI adoption in manufacturing, focusing on the importance of human-AI collaboration.
# 9. [16] Title: Industrial AI in action: How AI agents and digital threads will ... - This article discusses the potential of industrial AI in manufacturing, including its applications and benefits.
# 10. [17] Title: Five manufacturing trends being reshaped by AI - Google Cloud - This article highlights five manufacturing trends that are being reshaped by AI, including predictive maintenance and quality control.
#
# **Partially Relevant Results:**
#
# 1. [1] Title: AI in Manufacturing : Key Use Cases and benefits for 2025 and Beyond - This article provides an overview of AI applications in manufacturing, but its content is not as comprehensive as other results.
# 2. [6] Title: AI in manufacturing: transforming the industry - alten.com - This article discusses the impact of AI on manufacturing, but its content is not as detailed as other results.
# 3. [8] Title: AI-Powered Cost Optimization: How Smart Companies Are Slashing Expenses ... - This article discusses AI-powered cost optimization in manufacturing, but its content is not as directly relevant to the research topic as other results.
# 4. [9] Title: AI Development Costs in 2025: Trends, Challenges & Smart Budgeting for ... - This article discusses AI development costs in manufacturing, but its content is not as directly relevant to the research topic as other results.
# 5. [11] Title: 40 Detailed Artificial Intelligence Case Studies [2025] - This article presents 40 case studies of AI adoption, but only a few are directly relevant to manufacturing.
# 6. [12] Title: 5 Digital Transformation in Manufacturing Case Studies [2025] - This article presents five case studies of digital transformation in manufacturing, but only a few are directly relevant to AI adoption.
# 7. [13] Title: Eight AI Case Studies Demonstrate the Potential of AI in Manufacturing - This article presents eight case studies of AI adoption in manufacturing, but its content is not as comprehensive as other results.
# 8. [18] Title: Top 5 AI Adoption Challenges for 2025: Overcoming Barriers to Success - This article discusses AI adoption challenges in manufacturing, but its content is not as directly relevant to the research topic as other results.
# 9. [19] Title: Unlocking AI's Potential: Overcoming Barriers To Adoption - Forbes - This article discusses AI adoption challenges in general, but its content is not as directly relevant to manufacturing as other results.
# 10. [20] Title: Beyond The Hype: Confronting And Conquering AI Adoption Challenges - Forbes - This article discusses AI adoption challenges in general, but its content is not as directly relevant to manufacturing as other results.
#
# **Irrelevant Results:**
#
# None of the results are completely irrelevant to the research topic. However, some results may be more relevant to specific aspects of AI adoption in manufacturing, such as cost optimization or digital transformation.
#
# **Ranking of Relevant Results:**
#
# Based on the evaluation, the top 10 relevant results are:
#
# 1. [2] Title: How is AI being used in Manufacturing | IBM
# 2. [3] Title: Manufacturing AI: Top 15 tools & 13 real-life use cases ['25]
# 3. [4] Title: Key AI Applications In Manufacturing - Forbes
# 4. [5] Title: Adopting AI in manufacturing at speed and scale | McKinsey
# 5. [7] Title: Stats & Impact of AI in Manufacturing [2025]
# 6. [10] Title: How can AI be Used in Manufacturing? [15 Case Studies] [2025]
# 7. [14] Title: AI in Manufacturing in 2025: Transforming the Future of Industry
# 8. [15] Title: Best Practices For AI In Manufacturing: Expanding Human Potential - Forbes
# 9. [16] Title: Industrial AI in action: How AI agents and digital threads will ...
# 10. [17] Title: Five manufacturing trends being reshaped by AI - Google Cloud
# sources ranked by relevance [2, 3, 4, 5, 7, 10, 14, 15, 16, 17] (we will keep maximum of 10 sources, as defined by the user)
# LLM Filtering complete, kept 10 results

# %% [markdown]
# ### STEP 5: Research Synthesis - Generating the Comprehensive Final Report
#
# We've now reached the culmination of our research process. After carefully gathering, refining, and filtering information through multiple stages, we're ready to synthesize everything into a cohesive, publication-quality report. This final step:
#
# 1. Integrates information from all selected sources into a unified narrative
# 2. Structures content logically with clear sections and progression of ideas
# 3. Provides proper citations for all factual claims and insights
# 4. Balances breadth and depth to create a thorough yet readable analysis
# 5. Preserves nuance and context from the original sources
#
# The synthesis process uses our specialized answer model, which excels at long-form, coherent content generation while maintaining factual accuracy. Let's generate our final research report:

# %%
def remove_thinking_tags_from_answer(answer: str) -> str:
    """Remove content within <think> tags"""
    while "<think>" in answer and "</think>" in answer:
        start = answer.find("<think>")
        end = answer.find("</think>") + len("</think>")
        answer = answer[:start] + answer[end:]
    return answer

async def generate_research_answer(topic: str, results: SearchResults, together_client: AsyncTogether, answer_model: str, prompts: dict, max_tokens: int, remove_thinking_tags: bool = True) -> str:
    """
    Generate a comprehensive answer to the research topic based on the search results.

    Args:
        topic: The research topic
        results: Filtered search results to use for answer generation
        together_client: The Together AI client for LLM operations
        answer_model: Model to use for answer generation
        prompts: Dictionary of prompt templates
        max_tokens: Maximum number of tokens in the answer
        remove_thinking_tags: Whether to remove <think> tags from the answer

    Returns:
        Detailed research answer as a string
    """
    formatted_results = str(results)

    ANSWER_PROMPT = prompts["answer_prompt"]

    answer_response = await together_client.chat.completions.create(
        model=answer_model,
        messages=[
            {"role": "system", "content": ANSWER_PROMPT},
            {"role": "user", "content": f"Research Topic: {topic}\n\nSearch Results:\n{formatted_results}"}
        ],
        max_tokens=max_tokens
    )

    answer = answer_response.choices[0].message.content

    # Remove <think> tokens for reasoning models
    if remove_thinking_tags:
        answer = remove_thinking_tags_from_answer(answer)

    # Handle potential error cases
    if answer is None or not isinstance(answer, str):
        print("ERROR: No answer generated")
        return "No answer generated"

    return answer.strip()

# %%
research_answer = await generate_research_answer(research_topic, processed_results, together_client, answer_model, prompts, max_tokens)

# %%
from IPython.display import Markdown
display(Markdown(research_answer))
# Out:
# # The Impact of Artificial Intelligence on the Manufacturing Industry
#
# The manufacturing industry has witnessed significant transformations with the advent of Artificial Intelligence (AI). From improving efficiency and reducing costs to enhancing product quality and safety, AI has become a crucial component in modern manufacturing. This report synthesizes insights from various sources to provide a comprehensive understanding of AI's impact on the manufacturing industry.
#
# ## Introduction
#
# The integration of AI in manufacturing has been a gradual process, with its adoption accelerating over the past decade. As reported by McKinsey, the Global Lighthouse Network has identified 153 factories at the forefront of the Fourth Industrial Revolution (4IR), demonstrating a significant lead in AI adoption [3]. AI technologies have reached unprecedented levels of maturity, enabling machines to perform complex tasks in the cyber-physical world of production.
#
# ## Key Applications of AI in Manufacturing
#
# AI has numerous applications in manufacturing, including predictive maintenance, generative design, robotics, quality assurance, inventory management, process optimization, digital twins, edge analytics, price forecasting of raw materials, and logistics optimization. These applications have numerous benefits, including improved efficiency, reduced costs, enhanced product quality, and increased safety [1].
#
# Predictive maintenance, for instance, helps manufacturers forecast equipment failures, reducing downtime and costs. Generative design enables manufacturers to quickly produce thousands of design options for a single product, improving innovation capacity. Robotics and automation technologies have streamlined production processes, improving efficiency and reducing labor costs.
#
# ## Evolution of AI Adoption in Manufacturing
#
# The adoption of AI in manufacturing has evolved significantly over the past decade. Initially, AI was used for traditional automation, but it has now shifted to AI-driven systems that continuously learn and improve without direct human intervention. This shift has enabled greater flexibility, continuous process improvement, and the ability to respond to variable demands [4].
#
# Several core AI technologies have emerged as crucial in manufacturing, including machine learning, natural language processing (NLP), computer vision, and digital twin technology. These technologies have been applied in various real-world manufacturing scenarios, resulting in significant benefits, such as improved efficiency, reduced costs, and enhanced product quality.
#
# ## Benefits of AI in Manufacturing
#
# The benefits of AI in manufacturing are numerous. AI can help reduce operational expenses, increase productivity, and automate previously labor-intensive tasks. According to a report by ISG, manufacturers who have implemented AI in their operations have achieved significant cost savings and efficiency gains [5].
#
# For example, Siemens employed AI-driven solutions for predictive maintenance and process optimization, reducing downtime in industrial settings and increasing productivity. Adidas used AI-driven robotics and automation technologies in its factories to streamline production, resulting in increased production efficacy and reduced waste [6].
#
# ## Implementation Strategies and Best Practices
#
# To successfully integrate AI in manufacturing operations, companies should adopt a structured approach, clear use cases, and expert support. Best practices include capturing essential knowledge, enabling workers to do more, upskilling employees in real-time, expanding and elevating job roles, and attracting new talent [7].
#
# Additionally, manufacturers should develop a unified data framework, leverage AI agents and digital threads, foster collaboration and partnerships, invest in frontline worker development, and ensure scalability and interoperability. By adopting these strategies and best practices, manufacturers can overcome common barriers to AI adoption and successfully integrate AI into their operations.
#
# ## Challenges and Barriers to AI Adoption
#
# Despite the numerous benefits of AI in manufacturing, there are several challenges and barriers to its adoption. These include data quality, availability, and bias, privacy and security concerns, IT infrastructure integration, financial justification, and in-house expertise [10].
#
# To overcome these challenges, manufacturers should prioritize governance, transparency, and ethics, enhance data management practices, identify the right mix of solutions, craft a compelling case for investment, and find the right AI partner.
#
# ## Conclusion
#
# The impact of AI on the manufacturing industry has been significant, with numerous benefits, including improved efficiency, reduced costs, enhanced product quality, and increased safety. To successfully integrate AI in manufacturing operations, companies should adopt a structured approach, clear use cases, and expert support. By understanding the key applications, evolution, benefits, and challenges of AI in manufacturing, manufacturers can harness the full potential of AI to drive innovation and competitiveness in the industry.
#
# ## References
#
# [1] Manufacturing AI: Top 15 tools & 13 real-life use cases ['25]. https://research.aimultiple.com/manufacturing-ai/
#
# [2] Key AI Applications In Manufacturing - Forbes. https://www.forbes.com/councils/forbestechcouncil/2025/04/17/key-ai-applications-in-manufacturing/
#
# [3] Adopting AI in manufacturing at speed and scale | McKinsey. https://www.mckinsey.com/capabilities/operations/our-insights/adopting-ai-at-speed-and-scale-the-4ir-push-to-stay-competitive
#
# [4] AI in manufacturing: transforming the industry - alten.com. https://www.alten.com/ai-in-manufacturing-transforming-the-industry/
#
# [5] AI-Powered Cost Optimization: How Smart Companies Are Slashing Expenses .... https://isg-one.com/articles/ai-powered-cost-optimization--how-smart-companies-are-slashing-expenses-and-boosting-efficiency-in-2025
#
# [6] 40 Detailed Artificial Intelligence Case Studies [2025]. https://digitaldefynd.com/IQ/artificial-intelligence-case-studies/
#
# [7] Best Practices For AI In Manufacturing: Expanding Human Potential - Forbes. https://www.forbes.com/councils/forbestechcouncil/2025/02/19/best-practices-for-ai-in-manufacturing-expanding-human-potential/
#
# [8] Industrial AI in action: How AI agents and digital threads will .... https://www.microsoft.com/en-us/industry/blog/manufacturing-and-mobility/manufacturing/2025/03/25/industrial-ai-in-action-how-ai-agents-and-digital-threads-will-transform-the-manufacturing-industries/
#
# [9] Five manufacturing trends being reshaped by AI - Google Cloud. https://cloud.google.com/blog/topics/manufacturing/five-manufacturing-trends-being-reshaped-by-ai/
#
# [10] Top 5 AI Adoption Challenges for 2025: Overcoming Barriers to Success. https://convergetp.com/2025/03/25/top-5-ai-adoption-challenges-for-2025-overcoming-barriers-to-success/

# %% [markdown]
# #### Exporting and Sharing Research Results
#
# The final step in our research pipeline is to format and export the results for sharing, preservation, and presentation (e.g., html, pdf, slides, etc). Enjoy!

# %%
import markdown

# Convert to HTML
report_html = markdown.markdown(research_answer)

filename="research_report.html"
with open(filename, "w", encoding="utf-8") as f:
    f.write(report_html)

print(f"Research report saved as {filename}")
# Out:
# Research report saved as research_report.html

# %% [markdown]
# ## Limitations and Considerations
#
# While the Deep Search approach offers powerful research capabilities, it's important to understand its limitations and constraints:
#
# ### Information Constraints
# - **Recency Gap**: Search-based research is limited by the indexing latency of search engines. Very recent events or publications may not be captured.
# - **Access Limitations**: Some valuable information sources may be behind paywalls or otherwise inaccessible to the search system.
# - **Domain Specificity**: Highly specialized or technical domains may have limited indexing in general search engines.
#
# ### Processing Considerations
# - **Query Dependency**: The quality of results is heavily influenced by the initial and follow-up queries generated. Poorly formulated queries can lead to information gaps.
# - **Source Reliability**: While the system attempts to prioritize credible sources, it cannot perfectly assess the accuracy or bias of all content.
# - **Content Extraction Challenges**: Complex formats like tables, charts, or specialized notation may not be accurately captured in the content processing stage.
#
# ### Resource Requirements
# - **API Costs**: The system makes multiple calls to search and LLM APIs, which can incur significant costs for extensive research topics.
# - **Time Efficiency**: The iterative, multi-step nature of the process means it takes longer than simple RAG or direct LLM approaches.
# - **Model Dependencies**: The quality of outputs depends on having access to capable LLM models for different stages of the pipeline.
#
# ### Ethical Considerations
# - **Source Attribution**: While the system attempts to provide proper citations, it may not always perfectly attribute information to original creators.
# - **Content Bias**: The system may inadvertently amplify biases present in the indexed content or search ranking algorithms.
# - **Privacy Implications**: Research on certain topics may involve information with privacy sensitivities.
#
# Understanding these limitations helps set appropriate expectations and identify situations where this approach should be complemented with other research methodologies. For critical research needs, human review and validation remain essential.

# %% [markdown]
# ## Acknowledgements
#
# This cookbook relies on several key technologies and services that make advanced research capabilities possible:
#
# **[Tavily Search API](https://tavily.com/)**: Our cookbook leverages the Tavily API for efficient, high-quality web search functionality. Tavily provides comprehensive search results with raw content access, enabling our system to perform detailed content analysis. We are grateful to the Tavily team for providing this essential capability that forms the foundation of our information gathering process.
#
# **[Together AI](https://together.ai/)**: The LLM-powered components of our system are built using Together AI's API, which provides access to state-of-the-art language models optimized for different aspects of the research pipeline. Together AI's infrastructure enables the sophisticated analysis, planning, and synthesis capabilities that drive our research system.
#
# **Open Source Community**: This work builds upon numerous open-source libraries, tools, and research that have advanced the fields of natural language processing, information retrieval, and AI-assisted research. We acknowledge the broader community whose ongoing contributions make projects like this possible.
#
# If you use this cookbook in your own work or research, please consider acknowledging both Tavily and Together AI for their enabling technologies.
#
#
# ## Related
#
# Open source developers across the tech landscape have launched several meaningful attempts to recreate the capabilities of OpenAI's Deep Researcher. Some notable ones are as follows:
#
# * [Huggingface](https://huggingface.co/blog/open-deep-research)
# * [Open Deep Research](https://github.com/nickscamara/open-deep-research)
